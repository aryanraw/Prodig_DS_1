# %% [markdown]
# # Total Population of India

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# loading dataset

# %%
df = pd.read_csv("/content/world total (population).csv",encoding='utf-8')
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %% [markdown]
# cleaning dataset

# %%
df_final = df.drop(['Country Code','Indicator Name','Indicator Code'],axis=1)

# %% [markdown]
# ploting bar graph

# %%
chosen_country = 'India'
country_data = df_final[df_final['Country Name'] == chosen_country]
years = country_data.columns[2:].astype('string')
population = country_data.iloc[:, 2:].values.flatten()
plt.figure(figsize=(9,3))
plt.bar(years, population, color='skyblue', edgecolor='black')
plt.xlabel('Year')
plt.ylabel('Population')
interval = 5
plt.gca().xaxis.set_major_locator(MultipleLocator(interval))
plt.title(f'Population of {chosen_country} Over the Years')
plt.show()

# %% [markdown]
# ploting histogram

# %%
plt.hist(population, bins=20, color='skyblue', edgecolor='black')
plt.show()

# %% [markdown]
# # Total Population of India (below 14)

# %% [markdown]
# loading dataset

# %%
df = pd.read_csv("/content/below 14 (total population).csv",encoding='utf-8')
df.head()
# Out:
#                   Country Name Country Code               Indicator Name  \
# 0                        Aruba          ABW  Population ages 0-14, total
# 1  Africa Eastern and Southern          AFE  Population ages 0-14, total
# 2                  Afghanistan          AFG  Population ages 0-14, total
# 3   Africa Western and Central          AFW  Population ages 0-14, total
# 4                       Angola          AGO  Population ages 0-14, total
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  SP.POP.0014.TO     23553.0     23970.0     24290.0     24520.0     24644.0
# 1  SP.POP.0014.TO  57766140.0  59417612.0  61174179.0  63018650.0  64954558.0
# 2  SP.POP.0014.TO   3589290.0   3665076.0   3746296.0   3835639.0   3934872.0
# 3  SP.POP.0014.TO  40188607.0  41133083.0  42129142.0  43225330.0  44444306.0
# 4  SP.POP.0014.TO   2262702.0   2324998.0   2388381.0   2453352.0   2519819.0
#
# ...

# %% [markdown]
# cleaning dataset

# %%
df_14final = df.drop(['Country Code','Indicator Name','Indicator Code'],axis=1)

# %% [markdown]
# ploting bar graph

# %%
chosen_country = 'India'
country_data = df_14final[df_14final['Country Name'] == chosen_country]
years = country_data.columns[2:].astype('string')
populationu14 = country_data.iloc[:, 2:].values.flatten()
plt.figure(figsize=(9,3))
plt.bar(years, populationu14, color='skyblue', edgecolor='black')
plt.xlabel('Year')
plt.ylabel('Population')
interval = 5
plt.gca().xaxis.set_major_locator(MultipleLocator(interval))
plt.title(f'Under 14 Population of {chosen_country} Over the Years')
plt.show()

# %% [markdown]
# ploting histogram

# %%
plt.hist(populationu14, bins=20, color='skyblue', edgecolor='black')
plt.show()

# %%
import time as t
while True:
  print('waiting')
  t.sleep(20)
# Out:
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# ...
